# %%
import PIL
from PIL import Image
out='/home/a1r/git/AM4doc/c96L33_am4p0_cmip6Diag/atmos_1980_2014/pcmdi_metrics_v1p1p1/'
epsout = out+'/epsdir/c96L33_am4p0_cmip6Diag.eps'
pngsout = out+'c96L33_am4p0_cmip6Diag.png'
Image.open(epsout)
# Out:
# <PIL.EpsImagePlugin.EpsImageFile image mode=RGB size=768x592 at 0x7F18C40CB790>
