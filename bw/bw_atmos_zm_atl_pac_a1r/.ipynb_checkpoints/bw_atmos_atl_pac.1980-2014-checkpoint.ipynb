# %% [markdown]
# ##### Analysis results using: bw_atmos_zm_atl_pac/run_zm_atl_pac.pl
# This script plots the zonal mean zonal wind stress over the ocean for
# the Atlantic and Pacific basins.
#
# Original author: Bruce Wyman, GFDL.
# To use this notebook, please ensure the Input parameters are set and run it in your jupyter notebook environment with all the dependencies installed from this gir repository.

# %% [markdown]
# Note:
# This notebook was run at GFDL in a Linux environment. The environment variables used along with software requirements is documented below for your reference.
#
# Please note that the data used by any script in this analysis suite can be found in the git repo to be able to reproduce the analysis in your local notebook. Any CMIP data references can be found in GFDL's Data Portal. Ref. http://data1.gfdl.noaa.gov
#
# in your env Flexible Runtime Environment. The following environment variables will allow a user to run this analysis script contained within the git repo without explicit "module load". But, the user is expected to copy the directories referenced in the following from the git repo. Also, we will set up an alias to gcp commands. GCP is a GFDL home-grown smart data transfer utility. For public facing scripts, it is enough that the user uses "cp" or other copy tools relevant to their runtime environment.
#
# Acknowledgment:
# GFDL Modeling Services and Data Portal Team.
# Bruce Wyman, Huan Guo et al.

# %% [markdown]
# Software Requirements
#
# 1. NCL 6.2.1
# 2. NETCDF 4.2
# 3. HDF 1.8.8
# 4. Python2.Xwith (subprocess,commands,os,sys,git)
#     Run using: 2.7.12 |Anaconda custom (64-bit)
#     [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# 5. NCO 4.3.1
# 6. PERL v5.10.1
# 7. intel_compilers/11.1.073

# %%
import os
os.environ['NCARG_ROOT']='/usr/local/x64/ncarg-6.2.1'
#Note: Any reference to gcp or globus can be disregarded if run in outside of GFDL. Copy (or other relevant) can be used to replace the use of gcp elsewhere. 
os.environ['PATH']='/usr/local/gcp/2.3.11:/usr/local/x64/globus/5.2.1/bin:/usr/local/x64/globus/5.2.1/sbin:/usr/local/x64/netcdf-4.2_optimized/bin:/usr/local/x64/nco-4.3.1/bin:/usr/local/x64/hdf5-1.8.8_optimized/bin:/usr/local/x64/intel/Compiler/11.1/073/bin/intel64:/usr/local/x64/ncarg-6.2.1/bin:/home/gfdl/bin:/usr/local/OSoverlay/bin:/bin:/usr/bin:/usr/local/x64/bin:/usr/local/bin:/usr/local/explorer/bin:/usr/local/pgi/linux86/bin:/usr/local/cleanscape:/usr/local/toolworks/totalview/bin:/usr/local/autodesk/maya/bin:.'
os.environ['LD_LIBRARY_PATH']='/usr/local/x64/globus/5.2.1/lib64:/usr/local/x64/nco-4.3.1/lib:/usr/local/x64/netcdf-4.2_optimized/lib:/usr/local/x64/hdf5-1.8.8_optimized/lib:/usr/local/x64/intel/Compiler/11.1/073/lib/intel64:/usr/local/globus/5.2.1/lib'
os.environ['CPATH'] ='/usr/local/x64/netcdf-4.2_optimized/include:/usr/local/x64/hdf5-1.8.8_optimized/include:/usr/local/x64/ncarg-6.2.1/include'
os.environ['TMPDIR'] = "/tmp/a1r/v4" # Please provide a temporary directory.
os.environ['FPATH']='/usr/local/x64/netcdf-4.2_optimized/include'
os.environ['LIBRARY_PATH']='/usr/local/x64/netcdf-4.2_optimized/lib:/usr/local/x64/hdf5-1.8.8_optimized/lib:/usr/local/x64/ncarg-6.2.1/lib'
os.environ['GLOBUS_LOCATION']='/usr/local/x64/globus/5.2.1'
os.environ['GLOBUS_PATH']='/usr/local/x64/globus/5.2.1'
os.environ['X509_CERT_DIR']='/usr/local/x64/globus/5.2.1/etc/grid-security/certificates'
os.environ['LIBPATH']='/usr/local/x64/globus/5.2.1/lib'
os.environ['SHLIB_PATH']='/usr/local/x64/globus/5.2.1/lib'
os.environ['X509_CERT_DIR']='/usr/local/x64/globus/5.2.1/etc/grid-security/certificates'
os.environ['FRE_ANALYSIS_ARCHIVE']='/archive/fms/fre-analysis/test' # Please see reference in git repo
os.environ['_LM_FILES_']='/usr/local/Modules/x64/modulefiles/ncarg/6.2.1:/usr/local/Modules/modulefiles/globus/5.2.1:/usr/local/Modules/x64/modulefiles/intel_compilers/11.1.073:/usr/local/Modules/modulefiles/gcp/2.3:/usr/local/Modules/x64/modulefiles/hdf5/1.8.8:/usr/local/Modules/x64/modulefiles/netcdf/4.2:/usr/local/Modules/x64/modulefiles/nco/4.3.1'
os.environ['MANPATH']='/usr/local/x64/nco-4.3.1/man:/usr/local/x64/netcdf-4.2_optimized/share/man:/usr/local/x64/intel/Compiler/11.1/073/man/en_US:/usr/local/globus/5.2.1/man:/home/gfdl/man:/usr/share/man:/usr/X11R6/man:/usr/local/x64/share/man:/usr/local/man:/usr/local/pgi/man:/usr/local/toolworks/totalview/man:/usr/local/ncarg/man'
os.environ['INTEL_LICENSE_FILE']='/usr/local/x64/intel/licenses'
#Turn on with appropriate values if this is relevant. For the current notebook, this is not mandatory- os.environ['FRE_ANALYSIS_GIT_URL']= 'file:///home/fms/local/opt/fre-analysis/git'

# %%
#!/usr/bin/python
############## load modules #####################
import subprocess,commands,os,sys
from subprocess import PIPE
from git import Repo

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Original Script and author: bw_atmos_zm_atl_pac.csh, Bruce Wyman (GFDL)
# Python Code wrappers, etc : Aparna Radhakrishnan (GFDL)
# Output: Creates figures in $out_dir/atmos_${yr1}_${yr2}
####INPUT PARAMETERS######
in_data_dir = '/archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr/' # Please see reference in  GFDL Data Portal 
in_data_file = 'atmos_cmip.1980-2014.{01,02,03,04,05,06,07,08,09,10,11,12}.nc'
descriptor = 'AM4.0'
out_dir= '/nbhome/a1r/bw/output/bw_atmos_atl_pac.csh.1980-2014/v0807/' #Please provide an output directory
yr1 = '1980'
yr2 = '2014'
#remove thisupon testing fremodule = "fre/bronx-12"
#remove this upon testing freanalysismodule = "fre-analysis/test"
BASEDIR="/home/a1r/ipy/Notebooks/Documentations/AM4Documentation/bw/bw_atmos_cru_ts" # Please see reference in git repo
########### end of analysis template variables  #######
platform = 'desktop'

# %%
####### load modules ###########
TMPDIR = os.environ["TMPDIR"]
if not os.path.exists(TMPDIR):
     os.makedirs(TMPDIR)
            
if ( platform == 'hpcs-csc' ) or ( platform == 'desktop'):
    print("Running script on non-GFDL machine and public repo: skip module load") 
else:
    print "ERROR: invalid platform: %s" % platform
    exit(1)

#---- Check if environment loaded correctly ---#

# 
try:  
    os.environ["FRE_ANALYSIS_GIT_URL"]
except KeyError: 
    sys.exit("ERROR: environment variable FRE_ANALYSIS_GIT_URL not set.Check module loads")

# clone the source code from the repository if it does not exist

GIT_REPOSITORY = os.environ.get('FRE_ANALYSIS_GIT_URL')+"/bw"
FRE_CODE_TAG = 'awg_v20170106'
PACKAGE_NAME = 'bw_atmos_zm_atl_pac'
FRE_CODE_BASE = BASEDIR+'/fre-analysis'

directory = FRE_CODE_BASE+"/"+PACKAGE_NAME 
if not os.path.exists(directory):
        if not os.path.exists(FRE_CODE_BASE):
            os.makedirs(FRE_CODE_BASE)

        os.chdir(FRE_CODE_BASE)

        repo = Repo.clone_from(GIT_REPOSITORY+"/"+PACKAGE_NAME+".git",directory,branch=FRE_CODE_TAG)
##################
# run the script
##################

fields = "(tauu pr curl)" # plot all fields by default

options = "-i "+in_data_dir+" -d "+descriptor+" -y "+yr1+","+yr2+" -o "+out_dir

command = FRE_CODE_BASE+"/"+PACKAGE_NAME+"/run_zm_atl_pac_public.pl -v tauu "+options+" "+in_data_file

print(command)

cmd = subprocess.Popen('tcsh -c "'+command+'"',shell=True,stdout=PIPE,stdin=PIPE, stderr=PIPE)
output, errors = cmd.communicate()
print output, errors
# Out:
# Running script on non-GFDL machine and public repo: skip module load
# /home/a1r/ipy/Notebooks/Documentations/AM4Documentation/bw/bw_atmos_cru_ts/fre-analysis/bw_atmos_zm_atl_pac/run_zm_atl_pac_public.pl -v tauu -i /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr/ -d AM4.0 -y 1980,2014 -o /nbhome/a1r/bw/output/bw_atmos_atl_pac.csh.1980-2014/v0807/ atmos_cmip.1980-2014.{01,02,03,04,05,06,07,08,09,10,11,12}.nc
# For variable "tauu" there were "0" local CMIP5 climo files found.
# #--- Copying CMIP5 Climatology ---
# gcp /archive/fms/fre-analysis/test/bw/bw_atmos_zm_atl_pac/tauu_Amon_CMIP5_197901-200812-clim.nc.tar.gz .
# mkdir -p models
# tar -xvf tauu_Amon_CMIP5_197901-200812-clim.nc.tar.gz -C models
# tauu_Amon_bcc-csm1-1_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_bcc-csm1-1_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_bcc-csm1-1_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_bcc-csm1-1-m_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_bcc-csm1-1-m_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_bcc-csm1-1-m_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_CanAM4_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_CanAM4_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_CanAM4_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_CanAM4_amip_r4i1p1_197901-200812-clim.nc
# tauu_Amon_CCSM4_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_CCSM4_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_CCSM4_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_CCSM4_amip_r4i1p1_197901-200812-clim.nc
# tauu_Amon_CCSM4_amip_r5i1p1_197901-200812-clim.nc
# tauu_Amon_CCSM4_amip_r7i1p1_197901-200812-clim.nc
# tauu_Amon_CNRM-CM5_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r10i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r4i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r5i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r6i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r7i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r8i1p1_197901-200812-clim.nc
# tauu_Amon_CSIRO-Mk3-6-0_amip_r9i1p1_197901-200812-clim.nc
# tauu_Amon_FGOALS-g2_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_FGOALS-s2_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_FGOALS-s2_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_FGOALS-s2_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-CM3_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-CM3_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-CM3_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-CM3_amip_r4i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-CM3_amip_r5i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-HIRAM-C180_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-HIRAM-C180_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-HIRAM-C180_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-HIRAM-C360_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_GFDL-HIRAM-C360_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_GISS-E2-R_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_GISS-E2-R_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_GISS-E2-R_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_GISS-E2-R_amip_r4i1p1_197901-200812-clim.nc
# tauu_Amon_GISS-E2-R_amip_r5i1p1_197901-200812-clim.nc
# tauu_Amon_GISS-E2-R_amip_r6i1p1_197901-200812-clim.nc
# tauu_Amon_GISS-E2-R_amip_r6i1p3_197901-200812-clim.nc
# tauu_Amon_HadGEM2-A_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_inmcm4_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-LR_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-LR_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-LR_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-LR_amip_r4i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-LR_amip_r5i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-LR_amip_r6i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-MR_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-MR_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5A-MR_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_IPSL-CM5B-LR_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_MIROC5_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_MIROC5_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_MPI-ESM-LR_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_MPI-ESM-LR_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_MPI-ESM-LR_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_MPI-ESM-MR_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_MPI-ESM-MR_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_MPI-ESM-MR_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_MRI-AGCM3-2H_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_MRI-AGCM3-2H_amip_r1i1p2_197901-200812-clim.nc
# tauu_Amon_MRI-AGCM3-2H_amip_r1i1p3_197901-200812-clim.nc
# tauu_Amon_MRI-AGCM3-2S_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_MRI-CGCM3_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_MRI-CGCM3_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_MRI-CGCM3_amip_r3i1p1_197901-200812-clim.nc
# tauu_Amon_NorESM1-M_amip_r1i1p1_197901-200812-clim.nc
# tauu_Amon_NorESM1-M_amip_r2i1p1_197901-200812-clim.nc
# tauu_Amon_NorESM1-M_amip_r3i1p1_197901-200812-clim.nc
# tauu_filelist.log
# rm -f tauu_Amon_CMIP5_197901-200812-clim.nc.tar.gz
# mkdir -p cmip5
# ncea -h -p models tauu_Amon_IPSL-CM5A-LR_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_IPSL-CM5A-LR_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_IPSL-CM5A-LR_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_IPSL-CM5A-LR_amip_r4i1p1_197901-200812-clim.nc tauu_Amon_IPSL-CM5A-LR_amip_r5i1p1_197901-200812-clim.nc tauu_Amon_IPSL-CM5A-LR_amip_r6i1p1_197901-200812-clim.nc cmip5/tauu_Amon_IPSL-CM5A-LR_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_MPI-ESM-LR_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_MPI-ESM-LR_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_MPI-ESM-LR_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_MPI-ESM-LR_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_GFDL-CM3_amip_r5i1p1_197901-200812-clim.nc tauu_Amon_GFDL-CM3_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_GFDL-CM3_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_GFDL-CM3_amip_r4i1p1_197901-200812-clim.nc tauu_Amon_GFDL-CM3_amip_r2i1p1_197901-200812-clim.nc cmip5/tauu_Amon_GFDL-CM3_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_GFDL-HIRAM-C360_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_GFDL-HIRAM-C360_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_GFDL-HIRAM-C360_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_GISS-E2-R_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_GISS-E2-R_amip_r6i1p1_197901-200812-clim.nc tauu_Amon_GISS-E2-R_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_GISS-E2-R_amip_r6i1p3_197901-200812-clim.nc tauu_Amon_GISS-E2-R_amip_r5i1p1_197901-200812-clim.nc tauu_Amon_GISS-E2-R_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_GISS-E2-R_amip_r4i1p1_197901-200812-clim.nc cmip5/tauu_Amon_GISS-E2-R_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_IPSL-CM5A-MR_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_IPSL-CM5A-MR_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_IPSL-CM5A-MR_amip_r2i1p1_197901-200812-clim.nc cmip5/tauu_Amon_IPSL-CM5A-MR_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_FGOALS-s2_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_FGOALS-s2_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_FGOALS-s2_amip_r2i1p1_197901-200812-clim.nc cmip5/tauu_Amon_FGOALS-s2_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_CNRM-CM5_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_CNRM-CM5_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_MIROC5_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_MIROC5_amip_r2i1p1_197901-200812-clim.nc cmip5/tauu_Amon_MIROC5_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_NorESM1-M_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_NorESM1-M_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_NorESM1-M_amip_r2i1p1_197901-200812-clim.nc cmip5/tauu_Amon_NorESM1-M_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_GFDL-HIRAM-C180_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_GFDL-HIRAM-C180_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_GFDL-HIRAM-C180_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_GFDL-HIRAM-C180_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_MRI-AGCM3-2H_amip_r1i1p2_197901-200812-clim.nc tauu_Amon_MRI-AGCM3-2H_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_MRI-AGCM3-2H_amip_r1i1p3_197901-200812-clim.nc cmip5/tauu_Amon_MRI-AGCM3-2H_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_HadGEM2-A_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_HadGEM2-A_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_IPSL-CM5B-LR_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_IPSL-CM5B-LR_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_FGOALS-g2_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_FGOALS-g2_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_CCSM4_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_CCSM4_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_CCSM4_amip_r4i1p1_197901-200812-clim.nc tauu_Amon_CCSM4_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_CCSM4_amip_r7i1p1_197901-200812-clim.nc tauu_Amon_CCSM4_amip_r5i1p1_197901-200812-clim.nc cmip5/tauu_Amon_CCSM4_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_inmcm4_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_inmcm4_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_MRI-CGCM3_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_MRI-CGCM3_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_MRI-CGCM3_amip_r3i1p1_197901-200812-clim.nc cmip5/tauu_Amon_MRI-CGCM3_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_bcc-csm1-1_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_bcc-csm1-1_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_bcc-csm1-1_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_bcc-csm1-1_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_bcc-csm1-1-m_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_bcc-csm1-1-m_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_bcc-csm1-1-m_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_bcc-csm1-1-m_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_MRI-AGCM3-2S_amip_r1i1p1_197901-200812-clim.nc cmip5/tauu_Amon_MRI-AGCM3-2S_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_MPI-ESM-MR_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_MPI-ESM-MR_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_MPI-ESM-MR_amip_r2i1p1_197901-200812-clim.nc cmip5/tauu_Amon_MPI-ESM-MR_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_CanAM4_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_CanAM4_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_CanAM4_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_CanAM4_amip_r4i1p1_197901-200812-clim.nc cmip5/tauu_Amon_CanAM4_amip_r0i0p0_197901-200812-clim.nc
# ncea -h -p models tauu_Amon_CSIRO-Mk3-6-0_amip_r5i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r10i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r2i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r6i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r1i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r7i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r3i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r4i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r9i1p1_197901-200812-clim.nc tauu_Amon_CSIRO-Mk3-6-0_amip_r8i1p1_197901-200812-clim.nc cmip5/tauu_Amon_CSIRO-Mk3-6-0_amip_r0i0p0_197901-200812-clim.nc
# #--- Copying Observed Climatology: ---
# dmget /archive/fms/fre-analysis/test/bw/data/monthly/merra/land_mask.nc.gz /archive/fms/fre-analysis/test/bw/data/monthly/merra/taux.197901-201212.nc.gz /archive/fms/fre-analysis/test/bw/data/monthly/ecmwf/lsm.nc.gz /archive/fms/fre-analysis/test/bw/data/monthly/ecmwf/iews.197901-201212.nc.gz
# mkdir -p obs/merra
# gcp /archive/fms/fre-analysis/test/bw/data/monthly/merra/land_mask.nc.gz obs/merra/
# gunzip obs/merra/land_mask.nc.gz
# ncrename -h -v land_mask,sftlf obs/merra/land_mask.nc obs/merra/sftlf.nc
# gcp /archive/fms/fre-analysis/test/bw/data/monthly/merra/taux.197901-201212.nc.gz obs/merra/
# gunzip obs/merra/taux.197901-201212.nc.gz
# ncrename -h -v taux,tauu obs/merra/taux.197901-201212.nc
# mv obs/merra/taux.197901-201212.nc obs/merra/tauu.197901-201212.nc
# ncks -h -A obs/merra/sftlf.nc obs/merra/tauu.197901-201212.nc
# ncl 'ifile="obs/merra/tauu.197901-201212.nc"' 'ofile="obs/tauu.merra.climatology.nc"' yr1=1979 yr2=2008 /home/a1r/ipy/Notebooks/Documentations/AM4Documentation/bw/bw_atmos_cru_ts/fre-analysis/bw_atmos_zm_atl_pac/ncl/compute_monthly_climatology.ncl
#  Copyright (C) 1995-2014 - All Rights Reserved
#  University Corporation for Atmospheric Research
#  NCAR Command Language Version 6.2.1
#  The use of this software is governed by a License Agreement.
#  See http://www.ncl.ucar.edu/ for more details.
# (0)	Climatology computed from 1979 to 2008
# (0)	Time dimension (time) indices used 0 to 359 (full indices are 0 to 407)
# (0)	Registering variable: lat  dims=lat  type=double
# (0)	Registering variable: lon  dims=lon  type=double
# (0)	Registering variable: tauu  dims=time,lat,lon  type=float
# (0)	Registering variable: sftlf  dims=lat,lon  type=float
# (0)	writing static variable: lat
# (0)	writing static variable: lon
# (0)	writing time-varying variable: tauu
# (0)	Time series from 197901 to 200812
# (0)	writing static variable: sftlf
# mkdir -p obs/ecmwf
# gcp /archive/fms/fre-analysis/test/bw/data/monthly/ecmwf/lsm.nc.gz obs/ecmwf/
# gunzip obs/ecmwf/lsm.nc.gz
# ncrename -h -v lsm,sftlf obs/ecmwf/lsm.nc obs/ecmwf/sftlf.nc
# gcp /archive/fms/fre-analysis/test/bw/data/monthly/ecmwf/iews.197901-201212.nc.gz obs/ecmwf/
# gunzip obs/ecmwf/iews.197901-201212.nc.gz
# ncrename -h -v iews,tauu obs/ecmwf/iews.197901-201212.nc
# mv obs/ecmwf/iews.197901-201212.nc obs/ecmwf/tauu.197901-201212.nc
# ncks -h -A obs/ecmwf/sftlf.nc obs/ecmwf/tauu.197901-201212.nc
# ncl 'ifile="obs/ecmwf/tauu.197901-201212.nc"' 'ofile="obs/tauu.ecmwf.climatology.nc"' yr1=1979 yr2=2008 /home/a1r/ipy/Notebooks/Documentations/AM4Documentation/bw/bw_atmos_cru_ts/fre-analysis/bw_atmos_zm_atl_pac/ncl/compute_monthly_climatology.ncl
#  Copyright (C) 1995-2014 - All Rights Reserved
#  University Corporation for Atmospheric Research
#  NCAR Command Language Version 6.2.1
#  The use of this software is governed by a License Agreement.
#  See http://www.ncl.ucar.edu/ for more details.
# (0)	Climatology computed from 1979 to 2008
# (0)	Time dimension (time) indices used 0 to 359 (full indices are 0 to 407)
# (0)	Registering variable: tauu  dims=time,latitude,longitude  type=float
# (0)	Registering variable: latitude  dims=latitude  type=float
# (0)	Registering variable: longitude  dims=longitude  type=float
# (0)	Registering variable: sftlf  dims=latitude,longitude  type=float
# (0)	writing time-varying variable: tauu
# (0)	Time series from 197901 to 200812
# (0)	writing static variable: latitude
# (0)	writing static variable: longitude
# (0)	writing static variable: sftlf
# #--- Copying Model Climatology ---
# dmget /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.01.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.02.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.03.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.04.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.05.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.06.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.07.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.08.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.09.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.10.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.11.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.12.nc
# gcp /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.01.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.02.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.03.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.04.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.05.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.06.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.07.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.08.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.09.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.10.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.11.nc /archive/Huan.Guo/awg/warsaw/c96L33_am4p0_cmip6Diag/gfdl.ncrc4-intel-prod-openmp/pp/atmos_cmip/av/monthly_35yr//atmos_cmip.1980-2014.12.nc /tmp/a1r/v4/bw_tauu_atl_pac
# ncks -h -v sftlf atmos_cmip.1980-2014.01.nc sftlf.nc
# ncrcat -h -v tauu,climatology_bounds,lat_bnds,lon_bnds,average_T1,average_T2,average_DT atmos_cmip.1980-2014.01.nc atmos_cmip.1980-2014.02.nc atmos_cmip.1980-2014.03.nc atmos_cmip.1980-2014.04.nc atmos_cmip.1980-2014.05.nc atmos_cmip.1980-2014.06.nc atmos_cmip.1980-2014.07.nc atmos_cmip.1980-2014.08.nc atmos_cmip.1980-2014.09.nc atmos_cmip.1980-2014.10.nc atmos_cmip.1980-2014.11.nc atmos_cmip.1980-2014.12.nc model_climatology.nc
# mv model_climatology.nc tmp.model_climatology.nc
# ncap2 -h -s "tauu=-tauu" tmp.model_climatology.nc model_climatology.nc
# rm -f tmp.model_climatology.nc
# ncks -A -h sftlf.nc model_climatology.nc
# rm -f atmos_cmip.1980-2014.01.nc atmos_cmip.1980-2014.02.nc atmos_cmip.1980-2014.03.nc atmos_cmip.1980-2014.04.nc atmos_cmip.1980-2014.05.nc atmos_cmip.1980-2014.06.nc atmos_cmip.1980-2014.07.nc atmos_cmip.1980-2014.08.nc atmos_cmip.1980-2014.09.nc atmos_cmip.1980-2014.10.nc atmos_cmip.1980-2014.11.nc atmos_cmip.1980-2014.12.nc
# rm -f sftlf.nc
# #--- Running Plotting Routines ---
# ncl yr1=1979 yr2=2008 'model_descriptor="AM4.0 (1980-2014)"' 'psfile="tauu_atl_pac.ps"' 'variable="tauu"' /home/a1r/ipy/Notebooks/Documentations/AM4Documentation/bw/bw_atmos_cru_ts/fre-analysis/bw_atmos_zm_atl_pac/ncl/plot_zonal_clim.ncl
#  Copyright (C) 1995-2014 - All Rights Reserved
#  University Corporation for Atmospheric Research
#  NCAR Command Language Version 6.2.1
#  The use of this software is governed by a License Agreement.
#  See http://www.ncl.ucar.edu/ for more details.
# (0)	defining  CMIP5GRID@pacific
# (0)	defining  CMIP5DATA@pacific
# (0)	defining  CMIP5GRID@atlantic
# (0)	defining  CMIP5DATA@atlantic
# (0)	defining  CMIP5GRID@global
# (0)	defining  CMIP5DATA@global
# (0)	Model: bcc-csm1-1
# (0)	Model: bcc-csm1-1-m
# (0)	Model: CanAM4
# (0)	Model: CCSM4
# (0)	Model: CNRM-CM5
# (0)	Model: CSIRO-Mk3-6-0
# (0)	Model: FGOALS-g2
# (0)	Model: FGOALS-s2
# (0)	Model: GFDL-CM3
# (0)	Model: GFDL-HIRAM-C180
# (0)	Model: GFDL-HIRAM-C360
# (0)	Model: GISS-E2-R
# (0)	Model: HadGEM2-A
# (0)	Model: inmcm4
# (0)	Model: IPSL-CM5A-LR
# (0)	Model: IPSL-CM5A-MR
# (0)	Model: IPSL-CM5B-LR
# (0)	Model: MIROC5
# (0)	Model: MPI-ESM-LR
# (0)	Model: MPI-ESM-MR
# (0)	Model: MRI-AGCM3-2H
# (0)	Model: MRI-AGCM3-2S
# (0)	Model: MRI-CGCM3
# (0)	Model: NorESM1-M
# (0)	region: pacific
# (0)	region: atlantic
# (0)	region: global
# (0)	OBS: ecmwf
# (0)	OBS: merra
# (0)	Model: AM4.0 (1980-2014)
# (0)	season: Annual, region: Pacific (115E-100W)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0688029,0.17454
# (0)	season: Annual, region: Atlantic (70W-20E)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0758358,0.161952
# (0)	season: Annual, region: Land (Global)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0778347,0.475002
# (0)	season: DJF, region: Pacific (115E-100W)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.111719,0.159557
# (0)	season: DJF, region: Atlantic (70W-20E)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.108544,0.171613
# (0)	season: DJF, region: Land (Global)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.128591,0.585444
# (0)	season: MAM, region: Pacific (115E-100W)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0822564,0.195888
# (0)	season: MAM, region: Atlantic (70W-20E)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0762706,0.15627
# (0)	season: MAM, region: Land (Global)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0832328,0.394628
# (0)	season: JJA, region: Pacific (115E-100W)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0882508,0.148351
# (0)	season: JJA, region: Atlantic (70W-20E)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0818784,0.165957
# (0)	season: JJA, region: Land (Global)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.127165,0.345482
# (0)	season: SON, region: Pacific (115E-100W)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0690968,0.203833
# (0)	season: SON, region: Atlantic (70W-20E)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0758433,0.184553
# (0)	season: SON, region: Land (Global)
# (0)	  plotting cmip5: CMIP5 (24 models, 1979-2008)
# (0)	  plotting obs: ecmwf
# (0)	  plotting obs: merra
# (0)	  plotting model: AM4.0 (1980-2014)
# (0)	    mn,mx=-0.0977916,0.612432
# /home/a1r/ipy/Notebooks/Documentations/AM4Documentation/bw/bw_atmos_cru_ts/fre-analysis/bw_atmos_zm_atl_pac/shared/bw/addpagelabels.pl -O -l ANN,DJF,MAM,JJA,SON tauu_atl_pac.ps
# --- Saving Postscript File ---
# gzip  tauu_atl_pac.ps
# gcp -cd tauu_atl_pac.ps.gz gfdl:/nbhome/a1r/bw/output/bw_atmos_atl_pac.csh.1980-2014/v0807//atmos_1980_2014/Wyman.tauu_atl_pac/

# %% [markdown]
# ###### Output Figures are found in:  /home/a1r/git/bw_analysis/output/bw_atmos_atl_pac.csh.1980-2014/

# %% [markdown]
# UNCOMPRESS, AND DISPLAY FIGURES in PNG format

# %%
out_dir= '/nbhome/a1r/bw/output/bw_atmos_atl_pac.csh.1980-2014/v0807/'#Please provide reference to your output directory here

from IPython.display import Image
from IPython.display import display

import gzip,os,sys
path2file=out_dir
for root, dirs, files in os.walk(out_dir):
    path = root.split(os.sep)
    path2file = path2file+os.path.basename(root)+"/"
    for fl in files:
        if(fl.endswith(".ps.gz")):
                with gzip.open(path2file+fl, 'rb') as f:
                    file_content = f.read()
                    f.close()
                    fname = fl[:-3]
                    fname2 = fl[:-6]
                    uncompressed_path = os.path.join(path2file, fname)
                    open(uncompressed_path, 'w').write(file_content )
                cmd = 'convert %s %s/%s.png'%( uncompressed_path,path2file,fname2)
                os.system(cmd)
                for root, dirs, filepng in os.walk(path2file):
                    for f in filepng:
                        if(f.endswith(".png")):
                            display(Image(path2file+"/"+f)) #path2file+fname2+"-0.png"
